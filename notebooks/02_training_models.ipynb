# %% [markdown]
# # 02 Entrenamiento de modelos
#
# Entrena y compara modelos para `boost_candidate`.

# %%
from src.train import train_all
model, comparison, metadata = train_all(percentile=0.70)
comparison

# %%
metadata
