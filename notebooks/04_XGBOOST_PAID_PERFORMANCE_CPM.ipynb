# %% [markdown]
# # XGBoost rendimiento pagado y CPM
#
# Notebook de soporte generado para la tesis. Verifica el archivo `outputs/xgboost_paid_ads_metrics.csv` y deja el código reproducible para ejecutar desde la raíz del repo.

# %%
from pathlib import Path
ROOT=Path.cwd()
TARGET=ROOT/'outputs/xgboost_paid_ads_metrics.csv'
print('Existe:', TARGET.exists())
print('Archivo:', TARGET)
if TARGET.exists() and TARGET.suffix in ['.csv']:
    import pandas as pd
    display(pd.read_csv(TARGET).head())
elif TARGET.exists() and TARGET.suffix in ['.json']:
    import json
    data=json.load(open(TARGET, encoding='utf-8'))
    print(list(data)[:20])

# %%
# Reentrenamiento
# !python scripts/train_xgboost_paid_ads.py
