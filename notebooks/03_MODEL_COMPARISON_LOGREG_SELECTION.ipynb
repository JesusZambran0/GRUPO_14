# %% [markdown]
# # Comparación de algoritmos y selección de regresión logística
#
# Notebook de soporte generado para la tesis. Verifica el archivo `outputs/model_comparison.csv` y deja el código reproducible para ejecutar desde la raíz del repo.

# %%
from pathlib import Path
ROOT=Path.cwd()
TARGET=ROOT/'outputs/model_comparison.csv'
print('Existe:', TARGET.exists())
print('Archivo:', TARGET)
if TARGET.exists() and TARGET.suffix in ['.csv']:
    import pandas as pd
    display(pd.read_csv(TARGET).head())
elif TARGET.exists() and TARGET.suffix in ['.json']:
    import json
    data=json.load(open(TARGET, encoding='utf-8'))
    print(list(data)[:20])
