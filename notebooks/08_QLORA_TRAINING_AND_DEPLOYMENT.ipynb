# %% [markdown]
# # Entrenamiento y despliegue QLoRA/Qwen
#
# Notebook de soporte generado para la tesis. Verifica el archivo `scripts/train_qlora_qwen.py` y deja el código reproducible para ejecutar desde la raíz del repo.

# %%
from pathlib import Path
ROOT=Path.cwd()
TARGET=ROOT/'scripts/train_qlora_qwen.py'
print('Existe:', TARGET.exists())
print('Archivo:', TARGET)
if TARGET.exists() and TARGET.suffix in ['.csv']:
    import pandas as pd
    display(pd.read_csv(TARGET).head())
elif TARGET.exists() and TARGET.suffix in ['.json']:
    import json
    data=json.load(open(TARGET, encoding='utf-8'))
    print(list(data)[:20])

# %%
# Entrenamiento QLoRA opcional en GPU/Colab
# !python scripts/train_qlora_qwen.py
