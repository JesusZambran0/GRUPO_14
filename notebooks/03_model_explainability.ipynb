# %% [markdown]
# # 03 Explicabilidad
#
# Espacio para SHAP o feature importance del modelo final.

# %%
import joblib
from pathlib import Path
MODEL = Path("../models/best_model.joblib")
model = joblib.load(MODEL) if MODEL.exists() else None
model

# %%
# Si SHAP está instalado, agregar análisis aquí.
# import shap
# explainer = shap.Explainer(...)
