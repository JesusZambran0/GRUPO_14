# %% [markdown]
# # Auditoría de sustentabilidad
#
# Notebook de soporte generado para la tesis. Verifica el archivo `docs/THESIS_SUSTAINABILITY_AUDIT.md` y deja el código reproducible para ejecutar desde la raíz del repo.

# %%
from pathlib import Path
ROOT=Path.cwd()
TARGET=ROOT/'docs/THESIS_SUSTAINABILITY_AUDIT.md'
print('Existe:', TARGET.exists())
print('Archivo:', TARGET)
if TARGET.exists() and TARGET.suffix in ['.csv']:
    import pandas as pd
    display(pd.read_csv(TARGET).head())
elif TARGET.exists() and TARGET.suffix in ['.json']:
    import json
    data=json.load(open(TARGET, encoding='utf-8'))
    print(list(data)[:20])
